# %%
import pandas as pd
import numpy as np
data_path='/Users/kennetharguedas/Desktop/mos_lga.csv'
cols = ['station', 'model', 'runtime', 'ftime', 'n_x', 'tmp', 'dpt', 'cld',
       'wdr', 'wsp', 'p06', 'p12', 'q06', 'q12', 't06', 't12', 'snw', 'cig',
       'vis', 'obv', 'poz', 'pos', 'typ']
df=pd.read_csv(data_path, names=cols)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,5,6,8,9,10,11,12,13,16,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    station  model                 runtime                   ftime  n_x  tmp  \
# 0  station  model                 runtime                   ftime  n_x  tmp
# 1     KLGA    AVN  2000-05-30 12:00:00+00  2000-05-30 18:00:00+00  NaN   61
# 2     KLGA    AVN  2000-05-30 12:00:00+00  2000-05-30 21:00:00+00  NaN   64
# 3     KLGA    AVN  2000-05-30 12:00:00+00  2000-05-31 00:00:00+00  NaN   60
# 4     KLGA    AVN  2000-05-30 12:00:00+00  2000-05-31 03:00:00+00  NaN   57
#
#    dpt  cld  wdr  wsp ...   q12  t06  t12  snw  cig  vis  obv  poz  pos  typ
# 0  dpt  cld  wdr  wsp ...   q12  t06  t12  snw  cig  vis  obv  poz  pos  typ
# 1   43  NaN   70   14 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   44  NaN  110   14 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   46  NaN  130   12 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   47  NaN  120    9 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 23 columns]

# %%
#pd.read_csv?

# %%
cdf = df.drop(0, axis=0)

# %%
cdf
# Out:
#        station model                 runtime                   ftime  n_x tmp  \
# 1         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-30 18:00:00+00  NaN  61
# 2         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-30 21:00:00+00  NaN  64
# 3         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 00:00:00+00  NaN  60
# 4         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 03:00:00+00  NaN  57
# 5         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 06:00:00+00  NaN  55
# 6         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 09:00:00+00  NaN  54
# 7         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 12:00:00+00   53  56
# 8         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 15:00:00+00  NaN  62
# 9         KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 18:00:00+00  NaN  69
# 10        KLGA   AVN  2000-05-30 12:00:00+00  2000-05-31 21:00:00+00  NaN  69
# 11        KLGA   AVN  2000-05-30 12:00:00+00  2000-06-01 00:00:00+00   72  65
# ...

# %%
cdf['date'] = pd.to_datetime(cdf['runtime'])

# %%
cdf['tmp'] = cdf['tmp'].astype(float)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 534723 entries, 1 to 534723
# Data columns (total 24 columns):
# station    534723 non-null object
# model      534723 non-null object
# runtime    534723 non-null object
# ftime      534723 non-null object
# n_x        126895 non-null object
# tmp        532959 non-null float64
# dpt        532959 non-null object
# cld        533736 non-null object
# wdr        534723 non-null object
# wsp        534723 non-null object
# p06        277860 non-null object
# p12        126300 non-null object
# q06        267410 non-null object
# q12        121550 non-null object
# t06        277244 non-null object
# t12        12162 non-null object
# snw        36039 non-null object
# cig        533736 non-null object
# vis        516096 non-null object
# obv        516096 non-null object
# poz        400638 non-null object
# pos        400638 non-null object
# typ        400638 non-null object
# date       534723 non-null datetime64[ns]
# ...

# %%
cdf['date'].dt.time.head()
# Out:
# 1    12:00:00
# 2    12:00:00
# 3    12:00:00
# 4    12:00:00
# 5    12:00:00
# Name: date, dtype: object

# %%
hourly = cdf[['date','tmp']].groupby(cdf['date'].dt.time)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(15,5))

for hr, dfh in hourly:
    dfh.set_index('date').plot(ax=ax, label=hr)
_ = ax.legend(['0', '6', '12', '18'])

# %%
lga_inds=df['station'].str.match("KLGA")
lga=df[lga_inds]
datakeys=['runtime','tmp']

# %%
df['runtime']
# Out:
# 0                        runtime
# 1         2000-05-30 12:00:00+00
# 2         2000-05-30 12:00:00+00
# 3         2000-05-30 12:00:00+00
# 4         2000-05-30 12:00:00+00
# 5         2000-05-30 12:00:00+00
# 6         2000-05-30 12:00:00+00
# 7         2000-05-30 12:00:00+00
# 8         2000-05-30 12:00:00+00
# 9         2000-05-30 12:00:00+00
# 10        2000-05-30 12:00:00+00
# 11        2000-05-30 12:00:00+00
# 12        2000-05-30 12:00:00+00
# 13        2000-05-30 12:00:00+00
# 14        2000-05-30 12:00:00+00
# 15        2000-05-30 12:00:00+00
# 16        2000-05-30 12:00:00+00
# 17        2000-05-30 12:00:00+00
# 18        2000-05-30 12:00:00+00
# 19        2000-05-30 12:00:00+00
# 20        2000-05-30 12:00:00+00
# 21        2000-05-30 12:00:00+00
# 22        2000-05-31 00:00:00+00
# 23        2000-05-31 00:00:00+00
# 24        2000-05-31 00:00:00+00
# 25        2000-05-31 00:00:00+00
# 26        2000-05-31 00:00:00+00
# 27        2000-05-31 00:00:00+00
# ...

# %%
df['date'] = pd.to_datetime(df['runtime'])
print(df['date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c8092eb29f10> in <module>()
# ----> 1 df['date'] = pd.to_datetime(df['runtime'])
#       2 print(df['date'])
#
# ...

# %%
for (hr, dfh) in df[['date','tmp']].groupby(df['date'].dt.hour):
    dfh.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-d4a84e6ed307> in <module>()
# ----> 1 for (hr, dfh) in df[['date','tmp']].groupby(df['date'].dt.hour):
#       2     dfh.plot()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
# ...

# %%
list(df[['date', 'tmp']].groupby(df['date'].dt.hour))[0][-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-3d7f7f8c2926> in <module>()
# ----> 1 list(df[['date', 'tmp']].groupby(df['date'].dt.hour))[0][-1]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...
