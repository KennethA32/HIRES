# %%
import pandas as pd
import numpy as np
data_path='/Users/kennetharguedas/Desktop/obs_nyc.csv'
df=pd.read_csv(data_path)
print(df)
# Out:
#            STATION                              NAME  LATITUDE  LONGITUDE  \
# 0      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 1      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 2      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 3      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 4      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 5      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 6      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 7      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 8      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 9      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 10     USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# 11     USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# ...

# %%
print(df.keys())
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'FMTM', 'PGTM', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'TSUN',
#        'WDF2', 'WDF5', 'WESD', 'WSF2', 'WSF5', 'WT01', 'WT02', 'WT03', 'WT04',
#        'WT05', 'WT06', 'WT07', 'WT08', 'WT09', 'WT11', 'WT13', 'WT14', 'WT15',
#        'WT16', 'WT17', 'WT18', 'WT19', 'WT21', 'WT22', 'WV01', 'WV20'],
#       dtype='object')

# %%
lga_inds=df['NAME'].str.match("LA GUARDIA AIRPORT, NY US")
lga=df[lga_inds]
datakeys=['DATE', 'TAVG','TMIN', 'TMAX','PRCP']

# %%
df[datakeys]
# Out:
#              DATE  TAVG  TMIN  TMAX  PRCP
# 0      2000-01-01  42.0  34.0  50.0  0.00
# 1      2000-01-02  52.0  43.0  60.0  0.00
# 2      2000-01-03  58.0  51.0  64.0  0.00
# 3      2000-01-04  53.0  46.0  60.0  0.70
# 4      2000-01-05  38.0  29.0  47.0  0.00
# 5      2000-01-06  35.0  28.0  42.0  0.00
# 6      2000-01-07  42.0  35.0  49.0  0.00
# 7      2000-01-08  34.0  30.0  38.0  0.00
# 8      2000-01-09  44.0  37.0  51.0  0.02
# 9      2000-01-10  51.0  44.0  58.0  0.84
# 10     2000-01-11  46.0  40.0  52.0  0.00
# 11     2000-01-12  43.0  39.0  47.0  0.00
# 12     2000-01-13  29.0  18.0  39.0  0.05
# 13     2000-01-14  18.0  13.0  22.0  0.00
# 14     2000-01-15  24.0  17.0  30.0  0.00
# 15     2000-01-16  34.0  21.0  46.0  0.00
# 16     2000-01-17  14.0   7.0  21.0  0.00
# 17     2000-01-18  11.0   3.0  19.0  0.00
# 18     2000-01-19  20.0  10.0  29.0  0.00
# 19     2000-01-20  26.0  23.0  28.0  0.12
# 20     2000-01-21  17.0  10.0  23.0  0.00
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,5))
ax=fig.add_subplot(1,1,1)
lga['TMAX'].plot(ax=ax,color='blue', linestyle=':', alpha=.7)
lga['TMIN'].plot(ax=ax,color='blue', linestyle=':', alpha=.7)
lga['TAVG'].plot(ax=ax,color='red', alpha=.9)

# %%
lga_inds=df['NAME'].str.match("LA GUARDIA AIRPORT, NY US")
lga=df[lga_inds]
datakeys=['DATE', 'TAVG','TMIN', 'TMAX',]

# %%
lg2 = lga.set_index(pd.to_datetime(lga['DATE']))

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,5))
ax=fig.add_subplot(1,1,1)
lg2['PRCP'].plot(ax=ax,color='blue', linestyle=':', alpha=.8)
ax.grid(True, which='both', axis='x')
ax.set_ylim(0)
ax.set_xlim(lg2.index[0], lg2.index[-1])
#ax.stem(lga['DATE'], lga['PRCP'], '--')
#lga['TMIN'].plot(ax=ax,color='blue', linestyle=':', alpha=.7)
#lga['TAVG'].plot(ax=ax,color='red', alpha=.9)
# Out:
# (10957, 17719)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,5))
ax=fig.add_subplot(1,1,1)
lga['PRCP'].plot(ax=ax,color='purple', linestyle=':', alpha=.8)

# %%
ax.grid?

# %% [markdown]
# ##
# The average over the range

# %%
import matplotlib.pyplot as plt
lg2_range=lg2['TMAX'] - lg2['TMIN']
lg2_range.plot(alpha=.4)

# %%
lga_range=lga['TMAX'] - lga['TMIN']
lga_range.plot(alpha=.4)
lga['TAVG'].plot(color='red', alpha=.8)
#np.mean(lga_range)
np.std(lga_range)
# Out:
# 5.103488154642002

# %%
#lga_tmax_list = np.array(lga['TMAX']).tolist()
#np.mean(lga_tmax_list)

# %%
lga_tmax_mean = np.mean(lga['TMAX'])
lga_tmax_mean
# Out:
# 63.243862762496306

# %%
np.std(lga['TMAX'])
# Out:
# 18.292647455935757

# %%
lga_tmin_mean = np.mean(lga['TMIN'])
lga_tmin_mean
# Out:
# 49.66119491274771

# %%
np.std(lga['TMIN'])
# Out:
# 16.818510305627214

# %%
time = pd.date_range('2000-01-01', periods=2000, freq='360min')

# %%
series = pd.Series(np.random.randint(100, size=2000), index=time)

# %%
series[0:10]
# Out:
# 2000-01-01 00:00:00    11
# 2000-01-01 06:00:00    44
# 2000-01-01 12:00:00     4
# 2000-01-01 18:00:00    66
# 2000-01-02 00:00:00    76
# 2000-01-02 06:00:00    92
# 2000-01-02 12:00:00    41
# 2000-01-02 18:00:00    55
# 2000-01-03 00:00:00    43
# 2000-01-03 06:00:00    89
# Freq: 360T, dtype: int64

# %%
extract = series.str.match('00:00:00')
print(extract)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-180-c2a1d67a3a2f> in <module>()
# ----> 1 extract = series.str.match('00:00:00')
#       2 print(extract)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
# ...

# %%
series.groupby(series.index.hour).mean()
# Out:
# 0     50.208
# 6     51.506
# 12    47.874
# 18    50.564
# dtype: float64

# %%
df['date'] = pd.to_datetime(df['DATE'])

# %%
list(df.groupby(df['date'].dt.month))
# Out:
# [(1,
#              STATION                              NAME  LATITUDE  LONGITUDE  \
#   0      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   1      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   2      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   3      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   4      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   5      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   6      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   7      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   8      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   9      USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
#   10     USW00094728       NY CITY CENTRAL PARK, NY US  40.77898  -73.96925
# ...
